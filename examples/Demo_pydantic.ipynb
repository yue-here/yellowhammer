# %% [markdown]
# # Pydantic-AI datalab agent demo
#
# This demo queries a *datalab* instance populated by data from Josh Bocarsly's group at the University of Houston.

# %% [markdown]
# Enter LLM API key after running this cell (model choice to be added soon)

# %%
import os
import getpass

os.environ["ANTHROPIC_API_KEY"] = getpass.getpass("Enter your Anthropic API key")

# %% [markdown]
# Enter *datalab* API key and define the *datalab* instance URL

# %%
os.environ["DATALAB_API_KEY"] = getpass.getpass("Enter your Datalab API key")
os.environ["DATALAB_URL"] = "https://api.yellowhammer.datalab-org.io"

# %reload_ext yellowhammer

# %% [markdown]
# Use natural language to query the *datalab* instance, which contains data from multiple student projects:

# %%
# %%llm
# Can you give an overview of Moinak Dutta's research?
# Out:
# Based on the datalab records, Moinak Dutta appears to be conducting research focused on sodium-ion battery materials, specifically alpha-NaFeO2 (sodium iron oxide) cathode materials. The research involves:
#
# 1. Systematic synthesis of NaFeO2 samples with multiple preparation attempts (at least 7 different sample sets)
# 2. Detailed electrode preparation for battery testing
# 3. Electrochemical characterization through coin cell assemblies
# 4. Exploring variations in synthesis conditions, including:
#    - Different synthesis temperatures (450-650°C)
#    - Various cooling methods (air quench, furnace cooling, liquid nitrogen quenching)
#    - Investigating phase purity and material characteristics
#
# The research seems concentrated on developing and optimizing sodium-ion battery cathode materials, with a particular focus on understanding the synthesis parameters and electrochemical performance of NaFeO2. The project involves multiple experimental iterations, suggesting a rigorous approach to material development and characterization.
# Usage(requests=6,
#       request_tokens=45310,
#       response_tokens=427,
#       total_tokens=45737,
#       details=None)

# %% [markdown]
# The agent can synthesize information from multiple samples:

# %%
# %%llm
# Please write up a methods section for Moinak Dutta's experiments in the format of a JACS paper
# Out:
# Methods Section for NaFeO2 Synthesis and Electrochemical Characterization
#
# Materials Synthesis
# Alpha-NaFeO2 cathode materials were synthesized via a solid-state reaction method. Stoichiometric amounts of sodium carbonate (Na2CO3) and iron oxide (Fe2O3) were thoroughly ground together using a mortar and pestle to ensure homogeneous mixing. The precursor mixture was subsequently calcined in a muffle furnace at temperatures ranging from 450-650°C for 12 hours, with variations in cooling methods including air quenching, furnace cooling, and rapid cooling using liquid nitrogen.
#
# Electrode Preparation
# Electrode materials were prepared by mixing the synthesized NaFeO2 with carbon black and polyvinylidene fluoride (PVDF) binder in a 7:2:1 weight ratio. The mixture was homogenized using N-methyl-2-pyrrolidone (NMP) as a solvent. The resulting slurry was cast onto aluminum foil current collectors and dried under vacuum at 120°C for 12 hours.
#
# Electrochemical Characterization
# Coin cells (CR2032 type) were assembled in an argon-filled glove box using sodium metal as the counter electrode and a glass fiber separator. The electrolyte consisted of 1 M sodium hexafluorophosphate (NaPF6) dissolved in propylene carbonate. Electrochemical cycling was performed using a battery testing system, with galvanostatic charge-discharge measurements conducted between 2.0-4.5 V vs. Na+/Na at various current densities to evaluate the material's electrochemical performance.
#
# Structural and Morphological Analysis
# The crystalline structure of the synthesized NaFeO2 was characterized using X-ray diffraction (XRD), with particular attention to phase purity and potential beta-phase impurities. Scanning electron microscopy (SEM) and transmission electron microscopy (TEM) were employed to investigate the morphology and microstructure of the synthesized materials.
#
# Systematic Approach
# Multiple synthesis iterations (designated MD1-1 through MD7-1) were conducted to optimize synthesis parameters, with careful documentation of temperature, cooling method, and resulting material characteristics. Each experimental series involved repeated electrochemical testing to ensure reproducibility and reliability of the results.
# Usage(requests=8,
#       request_tokens=82151,
#       response_tokens=847,
#       total_tokens=82998,
#       details=None)
