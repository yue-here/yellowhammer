# %% [markdown]
# # Pydantic-AI datalab agent demo
#
# This demo queries a *datalab* instance populated by data from Josh Bocarsly's group at the University of Houston.

# %% [markdown]
# Enter LLM API key after running this cell (model choice to be added soon)

# %%
import os
import getpass

os.environ["ANTHROPIC_API_KEY"] = getpass.getpass("Enter your Anthropic API key")

# %% [markdown]
# Enter *datalab* API key and define the *datalab* instance URL

# %%
os.environ["DATALAB_API_KEY"] = getpass.getpass("Enter your Datalab API key")
os.environ["DATALAB_URL"] = "https://api.yellowhammer.datalab-org.io"

# %reload_ext yellowhammer

# %% [markdown]
# Use natural language to query the *datalab* instance, which contains data from multiple student projects:

# %%
# %%llm
# Can you give an overview of Moinak Dutta's research?
# Out:
# Based on the research items in the datalab, Moinak Dutta's research focuses on sodium-ion battery materials,
# specifically the synthesis and electrochemical characterization of sodium iron oxide (NaFeO2).
#
# Key research highlights include:
#
#  1 Developing advanced synthesis techniques for NaFeO2 materials
#  2 Exploring different synthesis parameters like temperature and starting materials
#  3 Preparing electrodes for coin cell battery testing
#  4 Systematically refining material synthesis to produce pure alpha-NaFeO2 phase
#
# The research is primarily centered on improving sodium-ion battery electrode materials through meticulous material
# synthesis and electrochemical characterization. Dutta has conducted extensive experiments on solid-state synthesis
# methods, varying conditions to optimize the material's structure and performance for potential battery applications.
# ...

# %% [markdown]
# The agent can synthesize information from multiple samples:

# %%
# %%llm
# Please write up a methods section for Moinak Dutta's experiments in the format of a JACS paper
# Out:
# Methods Section for NaFeO2 Synthesis and Characterization
#
# Synthesis of NaFeO2
#
# NaFeO2 was synthesized via a solid-state reaction method performed entirely within an argon-filled glovebox to minimize
# moisture and oxygen exposure. Stoichiometric amounts of sodium peroxide (Na2O2) and iron oxide (Fe2O3 or Fe3O4) were
# precisely weighed and thoroughly ground using a ceramic mortar and pestle. The mixed precursors were heated in an
# alumina crucible within a box furnace, with temperatures ranging from 450-650°C and a heating ramp of 5°C min-1.
# Synthesis protocols included 12-24 hour dwell times at target temperatures, with variations in quenching methods
# including air quench and liquid nitrogen quench.
#
# Electrode Preparation
#
# Coin cells were assembled in an argon-purged glovebox to ensure minimal moisture and oxygen contamination. Electrodes
# were prepared by mixing NaFeO2 powder with Super P carbon and polyvinylidene fluoride (PVDF) binder in
# ...

# %%
# %%llm
# Who are the main users of this datalab and what are their projects?
# Out:
# Based on the datalab contents, the main users and their projects include:
#
#  1 Hasindhi: Researching sodium nickel manganese oxide (Na-Ni-Mn-O) compounds for battery applications
#  2 Kusalvin Dabare: Specializing in sodium cobalt oxide (Na-Co-O) materials and their electrochemical properties
#  3 Moinak Dutta: Focusing on sodium iron oxide (NaFeO2) synthesis and characterization
#  4 Jason Zhou: Investigating manganese antimonide (MnSb) compounds
#  5 Matthew Evans: Contributing to X-ray diffraction analysis
#
# The datalab primarily supports research in advanced materials science, with a strong focus on:
#
#  • Sodium-ion battery material development
#  • Solid-state material synthesis
#  • Electrode preparation
#  • Electrochemical performance testing
#  • Crystal structure analysis
#
# The researchers appear to collaborate closely, sharing methodologies and techniques in material science, particularly in
# ...
